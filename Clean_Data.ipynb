# %% [markdown]
# ## Dependencies

# %%
import pandas as pd

# %% [markdown]
# ## Read Data

# %%
final_output = pd.read_excel('EdChoice Data Format.xlsx')
col_names = final_output.columns.tolist()
final_output
# Out:
# Empty DataFrame
# Columns: [Competition, District Name, District IRN, Building Name, Building IRN, Building Adress, Year, Preformance Index, School Type, White, Asian, Black, Hispanic, AYP Met?]
# Index: []

# %% [markdown]
# ## Year 2008 - 2009

# %%
# Read data with correct types
dtype_specification = {'Building IRN': str, 'District IRN': str, "Street address":str, 'City and Zip code':str} 
AY2009 = pd.read_excel('./2008-2009/0809_LRC_BUILDING.xls', dtype=dtype_specification)

# Drop bad rows 
AY2009 = AY2009.dropna(subset=[AY2009.columns[0]])
AY2009 = AY2009.dropna(subset=[AY2009.columns[1]])
AY2009 = AY2009.dropna(subset=[AY2009.columns[2]])
AY2009 = AY2009.dropna(subset=[AY2009.columns[3]])


def clean2009(row):
    new_row = ({
        'District Name' : row[3],
        'District IRN' : row[2],
        'Building Name' : row[1],
        'Building IRN' : row[0],
        'Building Adress' : str(row[6])+ " "+str(row[7]),
        'Year':2009,
        'Preformance Index':row[107],
        'School Type': row[10],
        'AYP Met?' : row[110]
    })
    final_output.loc[len(final_output)] = new_row
##    print(new_row)
    return row


AY2009 = AY2009.apply(clean2009, axis=1)
final_output
# Out:
#       Competition         District Name District IRN  \
# 0             NaN   Cleveland Municipal       043786
# 1             NaN  Ada Exempted Village       045187
# 2             NaN  Ada Exempted Village       045187
# 3             NaN         Sandusky City       044743
# 4             NaN         Hamilton City       044107
# ...           ...                   ...          ...
# 3694          NaN    Northwestern Local       050575
# 3695          NaN    South-Western City       044800
# 3696          NaN         Antwerp Local       048991
# 3697          NaN  East Muskingum Local       048835
# 3698          NaN          Jackson City       044156
#
#                                     Building Name Building IRN  \
# 0                                   Albert B Hart       000026
# 1                           Ada Elementary School       000059
# 2                                 Ada High School       000067
# 3                        Adams Junior High School       000083
# 4                         Adams Elementary School       000091
# ...                                           ...          ...
# 3694               Northwestern Elementary School       152116
# 3695                    Hayes Intermediate School       152132
# 3696                  Antwerp Local Middle School       152157
# 3697  Larry Miller Intermediate Elementary School       152280
# 3698          Jackson Southview Elementary School       152298
#
#                                         Building Adress  Year  \
# 0             3901 E 74th St Cleveland, OH   44105-3808  2009
# 1                    435 Grand Ave Ada, OH   45810-1013  2009
# 2                    435 Grand Ave Ada, OH   45810-1013  2009
# 3            318 Columbus Ave Sandusky, OH   44870-2616  2009
# 4                  450 S F St Hamilton, OH   45013-3245  2009
# ...                                                 ...   ...
# 3694       7334 N Elyria Rd West Salem, OH   44287-9790  2009
# 3695         4436 Haughn Rd Grove City, OH   43123-3219  2009
# 3696             303 S. Harrmann Rd Antwerp, OH   45813  2009
# 3697  13125 John Glenn School Rd New Concord, OH   4...  2009
# 3698      13842 State Route 93 Jackson, OH   45640-9761  2009
#
#       Preformance Index School Type  White  Asian  Black  Hispanic AYP Met?
# 0                  55.9         K-8    NaN    NaN    NaN       NaN  Not Met
# 1                  98.0         K-6    NaN    NaN    NaN       NaN      Met
# 2                  95.6        7-12    NaN    NaN    NaN       NaN      NaN
# 3                  87.4           7    NaN    NaN    NaN       NaN      Met
# 4                  96.1         K-6    NaN    NaN    NaN       NaN      Met
# ...                 ...         ...    ...    ...    ...       ...      ...
# 3694              102.9         K-5    NaN    NaN    NaN       NaN      Met
# 3695               97.1         5-6    NaN    NaN    NaN       NaN      Met
# 3696                NaN         6-8    NaN    NaN    NaN       NaN      NaN
# 3697              100.2         3-5    NaN    NaN    NaN       NaN      Met
# 3698               97.4  P,K,1-5,SN    NaN    NaN    NaN       NaN      Met
#
# [3699 rows x 14 columns]

# %% [markdown]
# ## Year 2009 - 2010

# %%
# Read data with correct types
dtype_specification = {'Building IRN': str, 'District IRN': str, "Street address":str, 'City and Zip code':str} 
AY2010 = pd.read_excel('./2009-2010/0910_LRC_BUILDING.xls', dtype=dtype_specification)

# Drop bad rows 
AY2010 = AY2010.dropna(subset=[AY2010.columns[0]])
AY2010 = AY2010.dropna(subset=[AY2010.columns[1]])
AY2010 = AY2010.dropna(subset=[AY2010.columns[2]])
AY2010 = AY2010.dropna(subset=[AY2010.columns[3]])


def clean2010(row):
    new_row = ({
        'District Name' : row[3],
        'District IRN' : row[2],
        'Building Name' : row[1],
        'Building IRN' : row[0],
        'Building Adress' : str(row[6])+ " "+str(row[7]),
        'Year':2010,
        'Preformance Index':row[95],
        'School Type': row[10],
        'AYP Met?' : row[101]
    })
    final_output.loc[len(final_output)] = new_row
##    print(new_row)
    return row


AY2010 = AY2010.apply(clean2010, axis=1)
final_output
# Out:
#       Competition         District Name District IRN  \
# 0             NaN   Cleveland Municipal       043786
# 1             NaN  Ada Exempted Village       045187
# 2             NaN  Ada Exempted Village       045187
# 3             NaN         Sandusky City       044743
# 4             NaN         Hamilton City       044107
# ...           ...                   ...          ...
# 7369          NaN    Northwestern Local       050575
# 7370          NaN    South-Western City       044800
# 7371          NaN         Antwerp Local       048991
# 7372          NaN  East Muskingum Local       048835
# 7373          NaN          Jackson City       044156
#
#                                     Building Name Building IRN  \
# 0                                   Albert B Hart       000026
# 1                           Ada Elementary School       000059
# 2                                 Ada High School       000067
# 3                        Adams Junior High School       000083
# 4                         Adams Elementary School       000091
# ...                                           ...          ...
# 7369               Northwestern Elementary School       152116
# 7370                    Hayes Intermediate School       152132
# 7371                  Antwerp Local Middle School       152157
# 7372  Larry Miller Intermediate Elementary School       152280
# 7373          Jackson Southview Elementary School       152298
#
#                                         Building Adress  Year  \
# 0             3901 E 74th St Cleveland, OH   44105-3808  2009
# 1                    435 Grand Ave Ada, OH   45810-1013  2009
# 2                    435 Grand Ave Ada, OH   45810-1013  2009
# 3            318 Columbus Ave Sandusky, OH   44870-2616  2009
# 4                  450 S F St Hamilton, OH   45013-3245  2009
# ...                                                 ...   ...
# 7369       7334 N Elyria Rd West Salem, OH   44287-9790  2010
# 7370         4436 Haughn Rd Grove City, OH   43123-3219  2010
# 7371             303 S. Harrmann Rd Antwerp, OH   45813  2010
# 7372  13125 John Glenn School Rd New Concord, OH   4...  2010
# 7373      13842 State Route 93 Jackson, OH   45640-9761  2010
#
#       Preformance Index School Type  White  Asian  Black  Hispanic AYP Met?
# 0                  55.9         K-8    NaN    NaN    NaN       NaN  Not Met
# 1                  98.0         K-6    NaN    NaN    NaN       NaN      Met
# 2                  95.6        7-12    NaN    NaN    NaN       NaN      NaN
# 3                  87.4           7    NaN    NaN    NaN       NaN      Met
# 4                  96.1         K-6    NaN    NaN    NaN       NaN      Met
# ...                 ...         ...    ...    ...    ...       ...      ...
# 7369              102.3         K-5    NaN    NaN    NaN       NaN      Met
# 7370              100.5         5-6    NaN    NaN    NaN       NaN      Met
# 7371               96.9         7-8    NaN    NaN    NaN       NaN      Met
# 7372              101.1         3-5    NaN    NaN    NaN       NaN  Not Met
# 7373               97.6  P,K,1-5,SN    NaN    NaN    NaN       NaN      Met
#
# [7374 rows x 14 columns]

# %% [markdown]
# ## Year 2010 - 2011

# %%
# Read data with correct types
dtype_specification = {'Building IRN': str, 'District IRN': str, "Street address":str, 'City and Zip code':str} 
AY2011 = pd.read_excel('./2010-2011/1011_LRC_BUILDING.xls', dtype=dtype_specification)

# Drop bad rows 
AY2011 = AY2011.dropna(subset=[AY2011.columns[0]])
AY2011 = AY2011.dropna(subset=[AY2011.columns[1]])
AY2011 = AY2011.dropna(subset=[AY2011.columns[2]])
AY2011 = AY2011.dropna(subset=[AY2011.columns[3]])


def clean2011(row):
    new_row = ({
        'District Name' : row[3],
        'District IRN' : row[2],
        'Building Name' : row[1],
        'Building IRN' : row[0],
        'Building Adress' : str(row[6])+ " "+str(row[7]),
        'Year':2011,
        'Preformance Index':row[94],
        'School Type': row[10],
        'AYP Met?' : row[101]
    })
    final_output.loc[len(final_output)] = new_row
##    print(new_row)
    return row


AY2011 = AY2011.apply(clean2011, axis=1)
final_output
# Out:
#        Competition         District Name District IRN  \
# 0              NaN   Cleveland Municipal       043786
# 1              NaN  Ada Exempted Village       045187
# 2              NaN  Ada Exempted Village       045187
# 3              NaN         Sandusky City       044743
# 4              NaN         Hamilton City       044107
# ...            ...                   ...          ...
# 10994          NaN    Northwestern Local       050575
# 10995          NaN    South-Western City       044800
# 10996          NaN         Antwerp Local       048991
# 10997          NaN  East Muskingum Local       048835
# 10998          NaN          Jackson City       044156
#
#                                      Building Name Building IRN  \
# 0                                    Albert B Hart       000026
# 1                            Ada Elementary School       000059
# 2                                  Ada High School       000067
# 3                         Adams Junior High School       000083
# 4                          Adams Elementary School       000091
# ...                                            ...          ...
# 10994               Northwestern Elementary School       152116
# 10995                    Hayes Intermediate School       152132
# 10996                  Antwerp Local Middle School       152157
# 10997  Larry Miller Intermediate Elementary School       152280
# 10998          Jackson Southview Elementary School       152298
#
#                                          Building Adress  Year  \
# 0              3901 E 74th St Cleveland, OH   44105-3808  2009
# 1                     435 Grand Ave Ada, OH   45810-1013  2009
# 2                     435 Grand Ave Ada, OH   45810-1013  2009
# 3             318 Columbus Ave Sandusky, OH   44870-2616  2009
# 4                   450 S F St Hamilton, OH   45013-3245  2009
# ...                                                  ...   ...
# 10994       7334 N Elyria Rd West Salem, OH   44287-9790  2011
# 10995         4436 Haughn Rd Grove City, OH   43123-3219  2011
# 10996             303 S. Harrmann Rd Antwerp, OH   45813  2011
# 10997  13125 John Glenn School Rd New Concord, OH   4...  2011
# 10998      13842 State Route 93 Jackson, OH   45640-9761  2011
#
#       Preformance Index School Type  White  Asian  Black  Hispanic AYP Met?
# 0                  55.9         K-8    NaN    NaN    NaN       NaN  Not Met
# 1                  98.0         K-6    NaN    NaN    NaN       NaN      Met
# 2                  95.6        7-12    NaN    NaN    NaN       NaN      NaN
# 3                  87.4           7    NaN    NaN    NaN       NaN      Met
# 4                  96.1         K-6    NaN    NaN    NaN       NaN      Met
# ...                 ...         ...    ...    ...    ...       ...      ...
# 10994                --         K-5    NaN    NaN    NaN       NaN      Met
# 10995                --         5-6    NaN    NaN    NaN       NaN      Met
# 10996                --         7-8    NaN    NaN    NaN       NaN      Met
# 10997                --         3-5    NaN    NaN    NaN       NaN      Met
# 10998                --  P,K,1-5,SN    NaN    NaN    NaN       NaN      Met
#
# [10999 rows x 14 columns]

# %% [markdown]
# ## Year 2011 - 2012

# %%
# Read data with correct types
dtype_specification = {'Building IRN': str, 'District IRN': str, "Street address":str, 'City and Zip code':str} 
AY2012 = pd.read_excel('./2011-2012/1112_LRC_BUILDING.xls', dtype=dtype_specification)

# Drop bad rows 
AY2012 = AY2012.dropna(subset=[AY2012.columns[0]])
AY2012 = AY2012.dropna(subset=[AY2012.columns[1]])
AY2012 = AY2012.dropna(subset=[AY2012.columns[2]])
AY2012 = AY2012.dropna(subset=[AY2012.columns[3]])


def clean2012(row):
    new_row = ({
        'District Name' : row[3],
        'District IRN' : row[2],
        'Building Name' : row[1],
        'Building IRN' : row[0],
        'Building Adress' : str(row[6])+ " "+str(row[7]),
        'Year':2012,
        'Preformance Index':row[94],
        'School Type': row[10],
        'AYP Met?' : row[97]
    })
    final_output.loc[len(final_output)] = new_row
##    print(new_row)
    return row


AY2012 = AY2012.apply(clean2012, axis=1)
final_output
# Out:
#        Competition         District Name District IRN  \
# 0              NaN   Cleveland Municipal       043786
# 1              NaN  Ada Exempted Village       045187
# 2              NaN  Ada Exempted Village       045187
# 3              NaN         Sandusky City       044743
# 4              NaN         Hamilton City       044107
# ...            ...                   ...          ...
# 14573          NaN    Northwestern Local       050575
# 14574          NaN    South-Western City       044800
# 14575          NaN         Antwerp Local       048991
# 14576          NaN  East Muskingum Local       048835
# 14577          NaN          Jackson City       044156
#
#                                      Building Name Building IRN  \
# 0                                    Albert B Hart       000026
# 1                            Ada Elementary School       000059
# 2                                  Ada High School       000067
# 3                         Adams Junior High School       000083
# 4                          Adams Elementary School       000091
# ...                                            ...          ...
# 14573               Northwestern Elementary School       152116
# 14574                    Hayes Intermediate School       152132
# 14575                  Antwerp Local Middle School       152157
# 14576  Larry Miller Intermediate Elementary School       152280
# 14577          Jackson Southview Elementary School       152298
#
#                                          Building Adress  Year  \
# 0              3901 E 74th St Cleveland, OH   44105-3808  2009
# 1                     435 Grand Ave Ada, OH   45810-1013  2009
# 2                     435 Grand Ave Ada, OH   45810-1013  2009
# 3             318 Columbus Ave Sandusky, OH   44870-2616  2009
# 4                   450 S F St Hamilton, OH   45013-3245  2009
# ...                                                  ...   ...
# 14573       7334 N Elyria Rd West Salem, OH   44287-9790  2012
# 14574         4436 Haughn Rd Grove City, OH   43123-3219  2012
# 14575             303 S. Harrmann Rd Antwerp, OH   45813  2012
# 14576  13125 John Glenn School Rd New Concord, OH   4...  2012
# 14577      13842 State Route 93 Jackson, OH   45640-9761  2012
#
#       Preformance Index School Type  White  Asian  Black  Hispanic AYP Met?
# 0                  55.9         K-8    NaN    NaN    NaN       NaN  Not Met
# 1                  98.0         K-6    NaN    NaN    NaN       NaN      Met
# 2                  95.6        7-12    NaN    NaN    NaN       NaN      NaN
# 3                  87.4           7    NaN    NaN    NaN       NaN      Met
# 4                  96.1         K-6    NaN    NaN    NaN       NaN      Met
# ...                 ...         ...    ...    ...    ...       ...      ...
# 14573             100.6         K-5    NaN    NaN    NaN       NaN      Met
# 14574             101.8         5-6    NaN    NaN    NaN       NaN      Met
# 14575             101.8         6-8    NaN    NaN    NaN       NaN      Met
# 14576             103.3         3-5    NaN    NaN    NaN       NaN      Met
# 14577             105.5  P,K,1-5,SN    NaN    NaN    NaN       NaN      Met
#
# [14578 rows x 14 columns]

# %% [markdown]
# ## Year 2012 - 2013

# %%
# Read data with correct types
dtype_specification = {'Building IRN': str, 'District IRN': str, "Street address":str, 'City and Zip code':str} 
AY2013 = pd.read_excel('./2012-2013/1213_LRC_BUILDING.xls', dtype=dtype_specification)

# Drop bad rows 
AY2013 = AY2013.dropna(subset=[AY2013.columns[0]])
AY2013 = AY2013.dropna(subset=[AY2013.columns[1]])
AY2013 = AY2013.dropna(subset=[AY2013.columns[2]])
AY2013 = AY2013.dropna(subset=[AY2013.columns[3]])


def clean2013(row):
    new_row = ({
        'District Name' : row[3],
        'District IRN' : row[2],
        'Building Name' : row[1],
        'Building IRN' : row[0],
        'Building Adress' : str(row[6])+ " "+str(row[7]),
        'Year':2013,
        'Preformance Index':row[17],
        'School Type': row[12],
    })
    final_output.loc[len(final_output)] = new_row
##    print(new_row)
    return row


AY2013 = AY2013.apply(clean2013, axis=1)
final_output
# Out:
#        Competition         District Name District IRN  \
# 0              NaN   Cleveland Municipal       043786
# 1              NaN  Ada Exempted Village       045187
# 2              NaN  Ada Exempted Village       045187
# 3              NaN         Sandusky City       044743
# 4              NaN         Hamilton City       044107
# ...            ...                   ...          ...
# 18033          NaN    Northwestern Local       050575
# 18034          NaN    South-Western City       044800
# 18035          NaN         Antwerp Local       048991
# 18036          NaN  East Muskingum Local       048835
# 18037          NaN          Jackson City       044156
#
#                                      Building Name Building IRN  \
# 0                                    Albert B Hart       000026
# 1                            Ada Elementary School       000059
# 2                                  Ada High School       000067
# 3                         Adams Junior High School       000083
# 4                          Adams Elementary School       000091
# ...                                            ...          ...
# 18033               Northwestern Elementary School       152116
# 18034                    Hayes Intermediate School       152132
# 18035                  Antwerp Local Middle School       152157
# 18036  Larry Miller Intermediate Elementary School       152280
# 18037          Jackson Southview Elementary School       152298
#
#                                          Building Adress  Year  \
# 0              3901 E 74th St Cleveland, OH   44105-3808  2009
# 1                     435 Grand Ave Ada, OH   45810-1013  2009
# 2                     435 Grand Ave Ada, OH   45810-1013  2009
# 3             318 Columbus Ave Sandusky, OH   44870-2616  2009
# 4                   450 S F St Hamilton, OH   45013-3245  2009
# ...                                                  ...   ...
# 18033       7334 N Elyria Rd West Salem, OH   44287-9790  2013
# 18034         4436 Haughn Rd Grove City, OH   43123-3219  2013
# 18035             303 S. Harrmann Rd Antwerp, OH   45813  2013
# 18036  13125 John Glenn School Rd New Concord, OH   4...  2013
# 18037      13842 State Route 93 Jackson, OH   45640-9761  2013
#
#       Preformance Index        School Type  White  Asian  Black  Hispanic  \
# 0                  55.9                K-8    NaN    NaN    NaN       NaN
# 1                  98.0                K-6    NaN    NaN    NaN       NaN
# 2                  95.6               7-12    NaN    NaN    NaN       NaN
# 3                  87.4                  7    NaN    NaN    NaN       NaN
# 4                  96.1                K-6    NaN    NaN    NaN       NaN
# ...                 ...                ...    ...    ...    ...       ...
# 18033           101.643  Elementary School    NaN    NaN    NaN       NaN
# 18034            97.050  Elementary School    NaN    NaN    NaN       NaN
# 18035           100.665      Middle School    NaN    NaN    NaN       NaN
# 18036           101.548  Elementary School    NaN    NaN    NaN       NaN
# 18037           103.765  Elementary School    NaN    NaN    NaN       NaN
#
#       AYP Met?
# 0      Not Met
# 1          Met
# 2          NaN
# 3          Met
# 4          Met
# ...        ...
# 18033      NaN
# 18034      NaN
# 18035      NaN
# 18036      NaN
# 18037      NaN
#
# [18038 rows x 14 columns]

# %% [markdown]
# ## 2013-2014

# %%
# Read data with correct types
dtype_specification = {'Building IRN': str, 'District IRN': str, "Street address":str, 'City and Zip code':str} 
AY2014 = pd.read_excel('./2013-2014/1314_LRC_BUILDING.xls', dtype=dtype_specification)

# Drop bad rows 
AY2014 = AY2014.dropna(subset=[AY2014.columns[0]])
AY2014 = AY2014.dropna(subset=[AY2014.columns[1]])
AY2014 = AY2014.dropna(subset=[AY2014.columns[2]])
AY2014 = AY2014.dropna(subset=[AY2014.columns[3]])


def clean2014(row):
    new_row = ({
        'District Name' : row[3],
        'District IRN' : row[2],
        'Building Name' : row[1],
        'Building IRN' : row[0],
        'Building Adress' : str(row[6])+ " "+str(row[7]),
        'Year':2014,
        'Preformance Index':row[17],
        'School Type': row[12],
        'Chronic Absenteeism Rate':row[105]
    })
    final_output.loc[len(final_output)] = new_row
##    print(new_row)
    return row


AY2014 = AY2014.apply(clean2014, axis=1)
final_output
# Out:
#        Competition         District Name District IRN  \
# 0              NaN   Cleveland Municipal       043786
# 1              NaN  Ada Exempted Village       045187
# 2              NaN  Ada Exempted Village       045187
# 3              NaN         Sandusky City       044743
# 4              NaN         Hamilton City       044107
# ...            ...                   ...          ...
# 21477          NaN    Northwestern Local       050575
# 21478          NaN    South-Western City       044800
# 21479          NaN         Antwerp Local       048991
# 21480          NaN  East Muskingum Local       048835
# 21481          NaN          Jackson City       044156
#
#                                      Building Name Building IRN  \
# 0                                    Albert B Hart       000026
# 1                            Ada Elementary School       000059
# 2                                  Ada High School       000067
# 3                         Adams Junior High School       000083
# 4                          Adams Elementary School       000091
# ...                                            ...          ...
# 21477               Northwestern Elementary School       152116
# 21478                    Hayes Intermediate School       152132
# 21479                  Antwerp Local Middle School       152157
# 21480  Larry Miller Intermediate Elementary School       152280
# 21481          Jackson Southview Elementary School       152298
#
#                                          Building Adress  Year  \
# 0              3901 E 74th St Cleveland, OH   44105-3808  2009
# 1                     435 Grand Ave Ada, OH   45810-1013  2009
# 2                     435 Grand Ave Ada, OH   45810-1013  2009
# 3             318 Columbus Ave Sandusky, OH   44870-2616  2009
# 4                   450 S F St Hamilton, OH   45013-3245  2009
# ...                                                  ...   ...
# 21477       7334 N Elyria Rd West Salem, OH   44287-9790  2014
# 21478         4436 Haughn Rd Grove City, OH   43123-3219  2014
# 21479             303 S. Harrmann Rd Antwerp, OH   45813  2014
# 21480  13125 John Glenn School Rd New Concord, OH   4...  2014
# 21481      13842 State Route 93 Jackson, OH   45640-9761  2014
#
#       Preformance Index        School Type  White  Asian  Black  Hispanic  \
# 0                  55.9                K-8    NaN    NaN    NaN       NaN
# 1                  98.0                K-6    NaN    NaN    NaN       NaN
# 2                  95.6               7-12    NaN    NaN    NaN       NaN
# 3                  87.4                  7    NaN    NaN    NaN       NaN
# 4                  96.1                K-6    NaN    NaN    NaN       NaN
# ...                 ...                ...    ...    ...    ...       ...
# 21477           102.832  Elementary School    NaN    NaN    NaN       NaN
# 21478           100.296  Elementary School    NaN    NaN    NaN       NaN
# 21479           101.370      Middle School    NaN    NaN    NaN       NaN
# 21480            99.088  Elementary School    NaN    NaN    NaN       NaN
# 21481           103.886  Elementary School    NaN    NaN    NaN       NaN
#
#       AYP Met?
# 0      Not Met
# 1          Met
# 2          NaN
# 3          Met
# 4          Met
# ...        ...
# 21477      NaN
# 21478      NaN
# 21479      NaN
# 21480      NaN
# 21481      NaN
#
# [21482 rows x 14 columns]

# %% [markdown]
# ## Year 2014 - 2015

# %%
# Read data with correct types
dtype_specification = {'Building IRN': str, 'District IRN': str, "Street address":str, 'City and Zip code':str} 
AY2015 = pd.read_excel('./2014-2015/1415_LRC_BUILDING.xls', dtype=dtype_specification)

# Drop bad rows 
AY2015 = AY2015.dropna(subset=[AY2015.columns[0]])
AY2015 = AY2015.dropna(subset=[AY2015.columns[1]])
AY2015 = AY2015.dropna(subset=[AY2015.columns[2]])
AY2015 = AY2015.dropna(subset=[AY2015.columns[3]])


def clean2015(row):
    new_row = ({
        'District Name' : row[3],
        'District IRN' : row[2],
        'Building Name' : row[1],
        'Building IRN' : row[0],
        'Building Adress' : str(row[6])+ " "+str(row[7]),
        'Year':2015,
        'Preformance Index':row[17],
        'School Type': row[12],
        'Chronic Absenteeism Rate':row[105]
    })
    final_output.loc[len(final_output)] = new_row
##    print(new_row)
    return row


AY2015 = AY2015.apply(clean2015, axis=1)
final_output
# Out:
#        Competition         District Name District IRN  \
# 0              NaN   Cleveland Municipal       043786
# 1              NaN  Ada Exempted Village       045187
# 2              NaN  Ada Exempted Village       045187
# 3              NaN         Sandusky City       044743
# 4              NaN         Hamilton City       044107
# ...            ...                   ...          ...
# 24892          NaN    Northwestern Local       050575
# 24893          NaN    South-Western City       044800
# 24894          NaN         Antwerp Local       048991
# 24895          NaN  East Muskingum Local       048835
# 24896          NaN          Jackson City       044156
#
#                                      Building Name Building IRN  \
# 0                                    Albert B Hart       000026
# 1                            Ada Elementary School       000059
# 2                                  Ada High School       000067
# 3                         Adams Junior High School       000083
# 4                          Adams Elementary School       000091
# ...                                            ...          ...
# 24892               Northwestern Elementary School       152116
# 24893                    Hayes Intermediate School       152132
# 24894                  Antwerp Local Middle School       152157
# 24895  Larry Miller Intermediate Elementary School       152280
# 24896          Jackson Southview Elementary School       152298
#
#                                          Building Adress  Year  \
# 0              3901 E 74th St Cleveland, OH   44105-3808  2009
# 1                     435 Grand Ave Ada, OH   45810-1013  2009
# 2                     435 Grand Ave Ada, OH   45810-1013  2009
# 3             318 Columbus Ave Sandusky, OH   44870-2616  2009
# 4                   450 S F St Hamilton, OH   45013-3245  2009
# ...                                                  ...   ...
# 24892       7334 N Elyria Rd West Salem, OH   44287-9790  2015
# 24893         4436 Haughn Rd Grove City, OH   43123-3219  2015
# 24894             303 S. Harrmann Rd Antwerp, OH   45813  2015
# 24895  13125 John Glenn School Rd New Concord, OH   4...  2015
# 24896      13842 State Route 93 Jackson, OH   45640-9761  2015
#
#       Preformance Index School Type  White  Asian  Black  Hispanic AYP Met?
# 0                  55.9         K-8    NaN    NaN    NaN       NaN  Not Met
# 1                  98.0         K-6    NaN    NaN    NaN       NaN      Met
# 2                  95.6        7-12    NaN    NaN    NaN       NaN      NaN
# 3                  87.4           7    NaN    NaN    NaN       NaN      Met
# 4                  96.1         K-6    NaN    NaN    NaN       NaN      Met
# ...                 ...         ...    ...    ...    ...       ...      ...
# 24892            97.272           8    NaN    NaN    NaN       NaN      NaN
# 24893            96.159           6    NaN    NaN    NaN       NaN      NaN
# 24894            93.390           8    NaN    NaN    NaN       NaN      NaN
# 24895            96.065           8    NaN    NaN    NaN       NaN      NaN
# 24896           102.078           8    NaN    NaN    NaN       NaN      NaN
#
# [24897 rows x 14 columns]

# %% [markdown]
# ## Year 2015 - 2016

# %%
# Read data with correct types
dtype_specification = {'Building IRN': str, 'District IRN': str, "Street address":str, 'City and Zip code':str} 
AY2016 = pd.read_excel('./2015-2016/1516_BUILDING_ACHIEVEMENT.xls', dtype=dtype_specification)

# Drop bad rows 
AY2016 = AY2016.dropna(subset=[AY2016.columns[0]])
AY2016 = AY2016.dropna(subset=[AY2016.columns[1]])
AY2016 = AY2016.dropna(subset=[AY2016.columns[2]])
AY2016 = AY2016.dropna(subset=[AY2016.columns[3]])


def clean2016(row):
    new_row = ({
        'District Name' : row[3],
        'District IRN' : row[2],
        'Building Name' : row[1],
        'Building IRN' : row[0],
        'Building Adress' : str(row[6])+ " "+str(row[7]),
        'Year':2016,
        'Preformance Index':row[10],
        'School Type': "?"
    })
    final_output.loc[len(final_output)] = new_row
##    print(new_row)
    return row


AY2016 = AY2016.apply(clean2016, axis=1)
final_output
# Out:
#        Competition         District Name District IRN  \
# 0              NaN   Cleveland Municipal       043786
# 1              NaN  Ada Exempted Village       045187
# 2              NaN  Ada Exempted Village       045187
# 3              NaN         Sandusky City       044743
# 4              NaN         Hamilton City       044107
# ...            ...                   ...          ...
# 28279          NaN    Northwestern Local       050575
# 28280          NaN    South-Western City       044800
# 28281          NaN         Antwerp Local       048991
# 28282          NaN  East Muskingum Local       048835
# 28283          NaN          Jackson City       044156
#
#                                      Building Name Building IRN  \
# 0                                    Albert B Hart       000026
# 1                            Ada Elementary School       000059
# 2                                  Ada High School       000067
# 3                         Adams Junior High School       000083
# 4                          Adams Elementary School       000091
# ...                                            ...          ...
# 28279               Northwestern Elementary School       152116
# 28280                    Hayes Intermediate School       152132
# 28281                  Antwerp Local Middle School       152157
# 28282  Larry Miller Intermediate Elementary School       152280
# 28283          Jackson Southview Elementary School       152298
#
#                                          Building Adress  Year  \
# 0              3901 E 74th St Cleveland, OH   44105-3808  2009
# 1                     435 Grand Ave Ada, OH   45810-1013  2009
# 2                     435 Grand Ave Ada, OH   45810-1013  2009
# 3             318 Columbus Ave Sandusky, OH   44870-2616  2009
# 4                   450 S F St Hamilton, OH   45013-3245  2009
# ...                                                  ...   ...
# 28279        7334 N Elyria Rd West Salem, OH, 44287-9790  2016
# 28280          4436 Haughn Rd Grove City, OH, 43123-3219  2016
# 28281              303 S. Harrmann Rd Antwerp, OH, 45813  2016
# 28282  13125 John Glenn School Rd New Concord, OH, 43...  2016
# 28283       13842 State Route 93 Jackson, OH, 45640-9761  2016
#
#       Preformance Index School Type  White  Asian  Black  Hispanic AYP Met?
# 0                  55.9         K-8    NaN    NaN    NaN       NaN  Not Met
# 1                  98.0         K-6    NaN    NaN    NaN       NaN      Met
# 2                  95.6        7-12    NaN    NaN    NaN       NaN      NaN
# 3                  87.4           7    NaN    NaN    NaN       NaN      Met
# 4                  96.1         K-6    NaN    NaN    NaN       NaN      Met
# ...                 ...         ...    ...    ...    ...       ...      ...
# 28279            98.036           ?    NaN    NaN    NaN       NaN      NaN
# 28280            93.498           ?    NaN    NaN    NaN       NaN      NaN
# 28281            89.474           ?    NaN    NaN    NaN       NaN      NaN
# 28282            95.236           ?    NaN    NaN    NaN       NaN      NaN
# 28283            99.824           ?    NaN    NaN    NaN       NaN      NaN
#
# [28284 rows x 14 columns]

# %% [markdown]
# ## Year 2016 - 2017

# %%
# Read data with correct types
dtype_specification = {'Building IRN': str, 'District IRN': str, "Street address":str, 'City and Zip code':str} 
AY2017 = pd.read_excel('./2016-2017/1617_BUILDING_ACHIEVEMENT.xls', dtype=dtype_specification)

# Drop bad rows 
AY2017 = AY2017.dropna(subset=[AY2017.columns[0]])
AY2017 = AY2017.dropna(subset=[AY2017.columns[1]])
AY2017 = AY2017.dropna(subset=[AY2017.columns[2]])
AY2017 = AY2017.dropna(subset=[AY2017.columns[3]])


def clean2017(row):
    new_row = ({
        'District Name' : row[3],
        'District IRN' : row[2],
        'Building Name' : row[1],
        'Building IRN' : row[0],
        'Building Adress' : str(row[6])+ " "+str(row[7]),
        'Year':2017,
        'Preformance Index':row[10],
        'School Type': "?"
    })
    final_output.loc[len(final_output)] = new_row
##    print(new_row)
    return row


AY2017 = AY2017.apply(clean2017, axis=1)
final_output
# Out:
#        Competition         District Name District IRN  \
# 0              NaN   Cleveland Municipal       043786
# 1              NaN  Ada Exempted Village       045187
# 2              NaN  Ada Exempted Village       045187
# 3              NaN         Sandusky City       044743
# 4              NaN         Hamilton City       044107
# ...            ...                   ...          ...
# 31653          NaN    Northwestern Local       050575
# 31654          NaN    South-Western City       044800
# 31655          NaN         Antwerp Local       048991
# 31656          NaN  East Muskingum Local       048835
# 31657          NaN          Jackson City       044156
#
#                                      Building Name Building IRN  \
# 0                                    Albert B Hart       000026
# 1                            Ada Elementary School       000059
# 2                                  Ada High School       000067
# 3                         Adams Junior High School       000083
# 4                          Adams Elementary School       000091
# ...                                            ...          ...
# 31653               Northwestern Elementary School       152116
# 31654                    Hayes Intermediate School       152132
# 31655                  Antwerp Local Middle School       152157
# 31656  Larry Miller Intermediate Elementary School       152280
# 31657          Jackson Southview Elementary School       152298
#
#                                          Building Adress  Year  \
# 0              3901 E 74th St Cleveland, OH   44105-3808  2009
# 1                     435 Grand Ave Ada, OH   45810-1013  2009
# 2                     435 Grand Ave Ada, OH   45810-1013  2009
# 3             318 Columbus Ave Sandusky, OH   44870-2616  2009
# 4                   450 S F St Hamilton, OH   45013-3245  2009
# ...                                                  ...   ...
# 31653        7334 N Elyria Rd West Salem, OH, 44287-9790  2017
# 31654          4436 Haughn Rd Grove City, OH, 43123-3219  2017
# 31655              303 S. Harrmann Rd Antwerp, OH, 45813  2017
# 31656  13125 John Glenn School Rd New Concord, OH, 43...  2017
# 31657       13842 State Route 93 Jackson, OH, 45640-9761  2017
#
#       Preformance Index School Type  White  Asian  Black  Hispanic AYP Met?
# 0                  55.9         K-8    NaN    NaN    NaN       NaN  Not Met
# 1                  98.0         K-6    NaN    NaN    NaN       NaN      Met
# 2                  95.6        7-12    NaN    NaN    NaN       NaN      NaN
# 3                  87.4           7    NaN    NaN    NaN       NaN      Met
# 4                  96.1         K-6    NaN    NaN    NaN       NaN      Met
# ...                 ...         ...    ...    ...    ...       ...      ...
# 31653            99.907           ?    NaN    NaN    NaN       NaN      NaN
# 31654            97.749           ?    NaN    NaN    NaN       NaN      NaN
# 31655            95.641           ?    NaN    NaN    NaN       NaN      NaN
# 31656            97.655           ?    NaN    NaN    NaN       NaN      NaN
# 31657           102.817           ?    NaN    NaN    NaN       NaN      NaN
#
# [31658 rows x 14 columns]

# %% [markdown]
# ## Year 2017 - 2018

# %%
# Read data with correct types
dtype_specification = {'Building IRN': str, 'District IRN': str, "Street address":str, 'City and Zip code':str} 
AY2018 = pd.read_excel('./2017-2018/17-18_Achievement_Building.xlsx', dtype=dtype_specification)

# Drop bad rows 
AY2018 = AY2018.dropna(subset=[AY2018.columns[0]])
AY2018 = AY2018.dropna(subset=[AY2018.columns[1]])
AY2018 = AY2018.dropna(subset=[AY2018.columns[2]])
AY2018 = AY2018.dropna(subset=[AY2018.columns[3]])


def clean2018(row):
    new_row = ({
        'District Name' : row[3],
        'District IRN' : row[2],
        'Building Name' : row[1],
        'Building IRN' : row[0],
        'Building Adress' : str(row[6])+ " "+str(row[7]),
        'Year':2018,
        'Preformance Index':row[10],
        'School Type': "?"
    })
    final_output.loc[len(final_output)] = new_row
##    print(new_row)
    return row


AY2018 = AY2018.apply(clean2018, axis=1)
final_output
# Out:
#        Competition         District Name District IRN  \
# 0              NaN   Cleveland Municipal       043786
# 1              NaN  Ada Exempted Village       045187
# 2              NaN  Ada Exempted Village       045187
# 3              NaN         Sandusky City       044743
# 4              NaN         Hamilton City       044107
# ...            ...                   ...          ...
# 35076          NaN    Northwestern Local       050575
# 35077          NaN    South-Western City       044800
# 35078          NaN         Antwerp Local       048991
# 35079          NaN  East Muskingum Local       048835
# 35080          NaN          Jackson City       044156
#
#                                      Building Name Building IRN  \
# 0                                    Albert B Hart       000026
# 1                            Ada Elementary School       000059
# 2                                  Ada High School       000067
# 3                         Adams Junior High School       000083
# 4                          Adams Elementary School       000091
# ...                                            ...          ...
# 35076               Northwestern Elementary School       152116
# 35077                    Hayes Intermediate School       152132
# 35078                  Antwerp Local Middle School       152157
# 35079  Larry Miller Intermediate Elementary School       152280
# 35080          Jackson Southview Elementary School       152298
#
#                                          Building Adress  Year  \
# 0              3901 E 74th St Cleveland, OH   44105-3808  2009
# 1                     435 Grand Ave Ada, OH   45810-1013  2009
# 2                     435 Grand Ave Ada, OH   45810-1013  2009
# 3             318 Columbus Ave Sandusky, OH   44870-2616  2009
# 4                   450 S F St Hamilton, OH   45013-3245  2009
# ...                                                  ...   ...
# 35076        7334 N Elyria Rd West Salem, OH, 44287-9790  2018
# 35077          4436 Haughn Rd Grove City, OH, 43123-3219  2018
# 35078              303 S. Harrmann Rd Antwerp, OH, 45813  2018
# 35079  13125 John Glenn School Rd New Concord, OH, 43...  2018
# 35080       13842 State Route 93 Jackson, OH, 45640-9761  2018
#
#       Preformance Index School Type  White  Asian  Black  Hispanic AYP Met?
# 0                  55.9         K-8    NaN    NaN    NaN       NaN  Not Met
# 1                  98.0         K-6    NaN    NaN    NaN       NaN      Met
# 2                  95.6        7-12    NaN    NaN    NaN       NaN      NaN
# 3                  87.4           7    NaN    NaN    NaN       NaN      Met
# 4                  96.1         K-6    NaN    NaN    NaN       NaN      Met
# ...                 ...         ...    ...    ...    ...       ...      ...
# 35076            97.691           ?    NaN    NaN    NaN       NaN      NaN
# 35077             99.02           ?    NaN    NaN    NaN       NaN      NaN
# 35078            90.704           ?    NaN    NaN    NaN       NaN      NaN
# 35079            99.925           ?    NaN    NaN    NaN       NaN      NaN
# 35080           101.787           ?    NaN    NaN    NaN       NaN      NaN
#
# [35081 rows x 14 columns]

# %%
final_output

final_output = final_output[(final_output['Preformance Index'].notnull()) & (final_output['Preformance Index'] != 0) & (final_output['Preformance Index'] != 'NC') & (final_output['Preformance Index'] != '--')]

final_output.to_csv('output.csv', index=False)

final_output
# Out:
#        Competition         District Name District IRN  \
# 0              NaN   Cleveland Municipal       043786
# 1              NaN  Ada Exempted Village       045187
# 2              NaN  Ada Exempted Village       045187
# 3              NaN         Sandusky City       044743
# 4              NaN         Hamilton City       044107
# ...            ...                   ...          ...
# 35076          NaN    Northwestern Local       050575
# 35077          NaN    South-Western City       044800
# 35078          NaN         Antwerp Local       048991
# 35079          NaN  East Muskingum Local       048835
# 35080          NaN          Jackson City       044156
#
#                                      Building Name Building IRN  \
# 0                                    Albert B Hart       000026
# 1                            Ada Elementary School       000059
# 2                                  Ada High School       000067
# 3                         Adams Junior High School       000083
# 4                          Adams Elementary School       000091
# ...                                            ...          ...
# 35076               Northwestern Elementary School       152116
# 35077                    Hayes Intermediate School       152132
# 35078                  Antwerp Local Middle School       152157
# 35079  Larry Miller Intermediate Elementary School       152280
# 35080          Jackson Southview Elementary School       152298
#
#                                          Building Adress  Year  \
# 0              3901 E 74th St Cleveland, OH   44105-3808  2009
# 1                     435 Grand Ave Ada, OH   45810-1013  2009
# 2                     435 Grand Ave Ada, OH   45810-1013  2009
# 3             318 Columbus Ave Sandusky, OH   44870-2616  2009
# 4                   450 S F St Hamilton, OH   45013-3245  2009
# ...                                                  ...   ...
# 35076        7334 N Elyria Rd West Salem, OH, 44287-9790  2018
# 35077          4436 Haughn Rd Grove City, OH, 43123-3219  2018
# 35078              303 S. Harrmann Rd Antwerp, OH, 45813  2018
# 35079  13125 John Glenn School Rd New Concord, OH, 43...  2018
# 35080       13842 State Route 93 Jackson, OH, 45640-9761  2018
#
#       Preformance Index School Type  White  Asian  Black  Hispanic AYP Met?
# 0                  55.9         K-8    NaN    NaN    NaN       NaN  Not Met
# 1                  98.0         K-6    NaN    NaN    NaN       NaN      Met
# 2                  95.6        7-12    NaN    NaN    NaN       NaN      NaN
# 3                  87.4           7    NaN    NaN    NaN       NaN      Met
# 4                  96.1         K-6    NaN    NaN    NaN       NaN      Met
# ...                 ...         ...    ...    ...    ...       ...      ...
# 35076            97.691           ?    NaN    NaN    NaN       NaN      NaN
# 35077             99.02           ?    NaN    NaN    NaN       NaN      NaN
# 35078            90.704           ?    NaN    NaN    NaN       NaN      NaN
# 35079            99.925           ?    NaN    NaN    NaN       NaN      NaN
# 35080           101.787           ?    NaN    NaN    NaN       NaN      NaN
#
# [30736 rows x 14 columns]
